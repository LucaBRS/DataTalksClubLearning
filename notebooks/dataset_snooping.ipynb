# %%
import eurostat
import pandas as pd
df = eurostat.get_data_df("tps00206") # marriage rate
df.head()
# Out:
#   freq indic_de geo\TIME_PERIOD  2013  2014  2015  2016  2017  2018  2019  \
# 0    A   GNUPRT              AD   NaN   NaN   NaN   NaN   NaN   3.9   NaN
# 1    A   GNUPRT              AL   8.2   8.2   8.7   7.8   7.9   8.1   7.9
# 2    A   GNUPRT              AM   NaN   NaN   5.9   5.4   5.1   5.0   5.3
# 3    A   GNUPRT              AT   4.3   4.4   5.1   5.1   5.1   5.3   5.2
# 4    A   GNUPRT              AZ   9.2   8.9   7.1   6.8   6.4   6.3   6.4
#
#    2020  2021  2022  2023  2024
# 0   NaN   NaN   NaN   NaN   NaN
# 1   6.2   7.0   6.8   NaN   6.8
# 2   NaN   NaN   NaN   5.5   NaN
# 3   4.4   NaN   NaN   5.0   5.0
# 4   NaN   NaN   6.1   NaN   NaN

# %%
import eurostat
import pandas as pd
df = eurostat.get_data_df("tps00014") # age at first marriage
df = df.sort_values(["geo\\TIME_PERIOD"])
df['indic_de'].unique()
# Out:
# <ArrowStringArray>
# ['FAGEMAR1', 'MAGEMAR1']
# Length: 2, dtype: str

# %%
import eurostat
import pandas as pd
df = eurostat.get_data_df("lfsa_ewhan2") # income quintiles
df.head()
# Out:
#   freq nace_r2 wstatus worktime     age sex unit geo\TIME_PERIOD  2008  2009  \
# 0    A       A    CFAM       FT  Y15-24   F   HR              AT   NaN   NaN
# 1    A       A    CFAM       FT  Y15-24   F   HR              BA   NaN   NaN
# 2    A       A    CFAM       FT  Y15-24   F   HR              BE   NaN   NaN
# 3    A       A    CFAM       FT  Y15-24   F   HR              BG   NaN   NaN
# 4    A       A    CFAM       FT  Y15-24   F   HR              CH   NaN   NaN
#
#    ...  2015  2016  2017  2018  2019  2020  2021  2022  2023  2024
# 0  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 25 columns]

# %%
import eurostat
import pandas as pd
df = eurostat.get_data_df("tps00216") # divorce rate
df.head()
# Out:
#   freq indic_de geo\TIME_PERIOD  2013  2014  2015  2016  2017  2018  2019  \
# 0    A   GDIVRT              AL   NaN   1.5   1.3   1.9   1.6   1.7   2.1
# 1    A   GDIVRT              AM   NaN   NaN   1.2   1.2   NaN   1.3   1.3
# 2    A   GDIVRT              AT   1.9   1.9   1.9   1.8   1.8   1.8   1.8
# 3    A   GDIVRT              AZ   1.2   1.3   1.3   1.3   1.5   1.5   1.7
# 4    A   GDIVRT              BE   2.2   2.2   2.2   2.1   2.0   2.0   2.0
#
#    2020  2021  2022  2023  2024
# 0   1.5   1.1   NaN   NaN   2.0
# 1   1.1   NaN   NaN   1.5   NaN
# 2   1.7   1.6   1.5   1.6   1.6
# 3   1.4   NaN   1.6   NaN   NaN
# 4   1.8   1.9   1.7   1.7   NaN

# %%
# Testing if bruin did write correctly to duckdb
import duckdb

with duckdb.connect(database='./data/duckdb.db') as conn:
    # print(conn.execute("SELECT * FROM information_schema.schemata").df())
    for table in ["load.divorce_rate", "load.age_at_marriage", "load.gender_pay_gap","load.marriage_rate"]:
        print(f"\n--- {table} ---")
        display(conn.execute(f"SELECT * FROM {table} ORDER BY country, year LIMIT 10").df())
    print(conn.execute("SELECT * FROM staging.hours_worked ORDER BY country, year LIMIT 20 ").df())
# Out:
# --- load.divorce_rate ---
#   country  year  divorce_rate
# 0      AL  2014           1.5
# 1      AL  2015           1.3
# 2      AL  2016           1.9
# 3      AL  2017           1.6
# 4      AL  2018           1.7
# 5      AL  2019           2.1
# 6      AL  2020           1.5
# 7      AL  2021           1.1
# 8      AL  2024           2.0
# 9      AM  2015           1.2
# --- load.age_at_marriage ---
#    indic_de country  year  age_at_marriage
# 0  FAGEMAR1      AM  2015             26.8
# 1  MAGEMAR1      AM  2015             30.8
# 2  FAGEMAR1      AM  2017             26.7
# 3  MAGEMAR1      AM  2017             31.0
# 4  FAGEMAR1      AM  2018             26.7
# 5  MAGEMAR1      AM  2018             31.0
# 6  FAGEMAR1      AT  2013             30.7
# 7  MAGEMAR1      AT  2013             33.3
# 8  FAGEMAR1      AT  2014             30.9
# 9  MAGEMAR1      AT  2014             33.6
# --- load.gender_pay_gap ---
#   country  year  gender_pay_gap
# ...

# %%
import eurostat
import pandas as pd
df = eurostat.get_data_df("lfsa_eegan2") # pay gap normal
df.head(50)
# Out:
#    freq     unit sex     age nace_r2 geo\TIME_PERIOD  2008  2009  2010  2011  \
# 0     A  THS_PER   F  Y15-19       A              AT   NaN   NaN   NaN   NaN
# 1     A  THS_PER   F  Y15-19       A              BA   NaN   NaN   NaN   NaN
# 2     A  THS_PER   F  Y15-19       A              BE   NaN   NaN   NaN   NaN
# 3     A  THS_PER   F  Y15-19       A              BG   NaN   NaN   NaN   NaN
# 4     A  THS_PER   F  Y15-19       A              CH   NaN   NaN   2.2   2.7
# 5     A  THS_PER   F  Y15-19       A              CY   NaN   NaN   NaN   NaN
# 6     A  THS_PER   F  Y15-19       A              CZ   NaN   NaN   NaN   NaN
# 7     A  THS_PER   F  Y15-19       A              DE   5.8   NaN   5.3   NaN
# 8     A  THS_PER   F  Y15-19       A              DK   NaN   NaN   NaN   NaN
# 9     A  THS_PER   F  Y15-19       A            EA21  23.7  19.9  17.0  17.0
# 10    A  THS_PER   F  Y15-19       A              EE   NaN   NaN   NaN   NaN
# ...

# %%
import eurostat
import pandas as pd
df = eurostat.get_data_df("earn_gr_gpgr2") # pay gap normal
df.head(50)
# Out:
#    freq unit nace_r2 geo\TIME_PERIOD  2007  2008  2009  2010  2011  2012  ...  \
# 0     A   PC       B              AL   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1     A   PC       B              AT   NaN   NaN   NaN  18.3   NaN   NaN  ...
# 2     A   PC       B              BE  -7.2  -8.8 -10.1 -13.4 -10.4  -7.1  ...
# 3     A   PC       B              BG  26.9  23.7  18.8  15.9  16.4  21.2  ...
# 4     A   PC       B              CH   NaN   7.8   7.7   5.2  10.4   9.6  ...
# 5     A   PC       B              CY   NaN  39.7  27.7  15.5  16.6  17.4  ...
# 6     A   PC       B              CZ   NaN  24.8  22.2  22.6  22.8  21.2  ...
# 7     A   PC       B              DE   5.1   6.8  10.5  12.3   9.8   7.0  ...
# 8     A   PC       B              DK   NaN  12.5  16.1  18.6  14.3  12.8  ...
# 9     A   PC       B              EE   NaN  37.2  36.5  36.0  34.0  37.0  ...
# 10    A   PC       B              EL   NaN   NaN   NaN  34.0   NaN   NaN  ...
# ...
